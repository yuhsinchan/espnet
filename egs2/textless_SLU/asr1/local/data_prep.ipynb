# %%
import os
import sys
import csv

# %%
atis_path = "/home/yuhsinchan/Documents/textless-SLU/atis"
train_BIO = os.path.join(atis_path, "sv_BIO_train.csv")
dev_BIO = os.path.join(atis_path, "sv_BIO_dev.csv")
test_BIO = os.path.join(atis_path, "sv_BIO_test.csv")

# %%
with open(train_BIO, "r") as f:
    reader = csv.reader(f)
    train_BIO_list = list(reader)

# %%
train_BIO_list
# Out:
# [['', 'id', 'label', 'transcription'],
#  ['0',
#   'rx0011ss',
#   'atis_flight BALTIMORE B-fromloc.city_name DALLAS B-toloc.city_name ROUND B-round_trip TRIP I-round_trip atis_flight',
#   'I WANT TO FLY FROM BALTIMORE TO DALLAS ROUND TRIP'],
#  ['1',
#   'sd00d1ss',
#   'atis_airfare ROUND B-round_trip TRIP I-round_trip BALTIMORE B-fromloc.city_name PHILADELPHIA B-toloc.city_name LESS B-cost_relative ONE B-fare_amount THOUSAND I-fare_amount DOLLARS I-fare_amount ROUND B-round_trip TRIP I-round_trip DENVER B-fromloc.city_name PHILADELPHIA B-toloc.city_name LESS B-cost_relative ONE B-fare_amount THOUSAND I-fare_amount DOLLARS I-fare_amount ROUND B-round_trip TRIP I-round_trip PITTSBURGH B-fromloc.city_name PHILADELPHIA B-toloc.city_name LESS B-cost_relative ONE B-fare_amount THOUSAND I-fare_amount DOLLARS I-fare_amount atis_airfare',
# ...

# %%
train_wav = os.listdir(os.path.join(atis_path, "train"))

# %%
for i in range(1, len(train_BIO_list)):
    if train_BIO_list[i][1] + ".wav" not in train_wav:
        print(train_BIO_list[i][1] + ".wav")
# Out:
# tx0022ss.wav
# ik0013ss.wav
# ik0013ss.wav
